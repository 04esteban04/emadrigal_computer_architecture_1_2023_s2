# %%
import cv2
import numpy as np

# %%
################################ Reajustar la dimesion de la imagen y la escala a gris ################################
# Cargar la imagen
imagen = cv2.imread('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiro.jpg')

# Cambiar la dimensión a 640x480
nueva_dimension = (640, 480)
imagen_redimensionada = cv2.resize(imagen, nueva_dimension)

# Convertir la imagen a escala de grises
imagen_gris = cv2.cvtColor(imagen_redimensionada, cv2.COLOR_BGR2GRAY)

# Convertir la imagen en escala de grises a un bytearray
byte_array = bytearray(imagen_gris)

# Guardar la imagen en escala de grises
cv2.imwrite('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroGris.jpg', imagen_gris)

a= len(byte_array)
print(a)
# Out:
# 307200

# %%
################################ Obtener txt con los pixeles de la imagen ################################
# Cargar la imagen
imagen = cv2.imread('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiro.jpg')

# Cambiar la dimensión a 640x480
nueva_dimension = (640, 480)
imagen_redimensionada = cv2.resize(imagen, nueva_dimension)

# Convertir la imagen a escala de grises
imagen_gris = cv2.cvtColor(imagen_redimensionada, cv2.COLOR_BGR2GRAY)

# Obtener las dimensiones de la imagen
alto, ancho = imagen_gris.shape

# Crear un archivo de texto para almacenar los valores de píxeles
archivo_txt = open('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroPixeles.txt', 'w')

# Iterar a través de la imagen y escribir los valores de píxeles en el archivo de texto
for fila in range(alto):
    for columna in range(ancho):
        valor_pixel = imagen_gris[fila, columna]
        archivo_txt.write(str(valor_pixel) + ' ')
    archivo_txt.write('\n')

# Cerrar el archivo de texto
archivo_txt.close()

print("Valores de píxeles guardados en 'sekiroPixeles.txt'")
# Out:
# Valores de píxeles guardados en 'sekiroPixeles.txt'

# %%
################################ Efecto rippling ################################

# Cargar los valores de píxeles desde el archivo de texto
with open('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroPixeles.txt', 'r') as archivo_txt:
    lineas = archivo_txt.readlines()

# Crear un nuevo archivo de texto para guardar los valores con efecto rippling
archivo_rippling = open('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroRippling.txt', 'w')

# Parámetros para el efecto rippling
amplitud_x = 10  # Ajusta la amplitud en dirección X según tu preferencia
frecuencia_x = 0.1  # Ajusta la frecuencia en dirección X según tu preferencia
amplitud_y = 10  # Ajusta la amplitud en dirección Y según tu preferencia
frecuencia_y = 0.1  # Ajusta la frecuencia en dirección Y según tu preferencia

# Aplicar el efecto rippling y escribir los nuevos valores en el archivo de texto
for linea in lineas:
    valores = linea.strip().split()  # Separar los valores de píxeles en la línea
    nuevos_valores = []

    for x, valor_pixel in enumerate(valores):
        x_rippling = x + amplitud_x * np.sin(2 * np.pi * frecuencia_x * x)
        y_rippling = amplitud_y * np.sin(2 * np.pi * frecuencia_y * x)
        
        x_rippling = int(np.clip(x_rippling, 0, len(valores) - 1))
        y_rippling = int(np.clip(y_rippling, 0, len(valores) - 1))
        nuevo_valor_pixel = valores[x_rippling]
        nuevos_valores.append(nuevo_valor_pixel)

    archivo_rippling.write(' '.join(nuevos_valores) + '\n')

# Cerrar el archivo de texto con efecto rippling
archivo_rippling.close()

print("Los valores con efecto rippling se han guardado en 'sekiroRippling.txt'.")
# Out:
# Los valores con efecto rippling se han guardado en 'sekiroRippling.txt'.

# %%
################################ Txt de pixeles a imagen ################################

# Cargar los valores de píxeles con efecto rippling desde el archivo de texto
with open('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroRippling.txt', 'r') as archivo_rippling:
    lineas = archivo_rippling.readlines()

# Crear una lista para almacenar los valores de píxeles
valores_pixel = []

for linea in lineas:
    valores = linea.strip().split()
    valores_pixel.append([int(valor) for valor in valores])

# Convertir la lista de valores de píxeles en una matriz NumPy
imagen_rippling = np.array(valores_pixel, dtype=np.uint8)

# Mostrar la imagen con efecto rippling
cv2.imshow('Imagen con efecto rippling', imagen_rippling)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Testeo

# %%
import cv2
import numpy as np

def rippling_effect(image_path, amplitude=20, frequency=10):
    # Cargar la imagen
    image = cv2.imread(image_path)

    # Obtener las dimensiones de la imagen
    height, width, _ = image.shape

    # Crear una imagen en blanco para el resultado
    rippling_image = np.zeros_like(image)

    # Aplicar el efecto rippling
    for y in range(height):
        for x in range(width):
            # Calcular la nueva posición basada en el efecto rippling
            new_x = x + amplitude * np.sin(2 * np.pi * y / frequency)
            new_y = y

            # Asegurarse de que las coordenadas estén dentro de los límites de la imagen
            if 0 <= new_x < width and 0 <= new_y < height:
                rippling_image[y, x] = image[int(new_y), int(new_x)]

    # Mostrar la imagen con el efecto rippling
    cv2.imshow("Rippling Effect", rippling_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

if __name__ == "__main__":
    image_path = "/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroGris.jpg"  # Reemplaza con la ruta de tu imagen
    rippling_effect(image_path, amplitude=20, frequency=10)

# %%
import cv2
import numpy as np

# Cargar la imagen en escala de grises
imagen_gris = cv2.imread('/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroGris.jpg', cv2.IMREAD_GRAYSCALE)

# Obtener las dimensiones de la imagen
alto, ancho = imagen_gris.shape

# Crear un factor de ondulación (ajusta según tus preferencias)
factor_ondulacion = 20

# Crear una copia de la lista de bytes
byte_array_ondulado = bytearray(imagen_gris)

# Aplicar el efecto de ondulación en una dimensión (horizontal en este ejemplo)
for y in range(alto):
    for x in range(ancho):
        nuevo_x = x + int(factor_ondulacion * np.sin(2 * np.pi * y / 100))
        if 0 <= nuevo_x < ancho:
            byte_array_ondulado[y * ancho + x] = byte_array[y * ancho + nuevo_x]

# Convertir byte_array_ondulado de nuevo en una imagen
imagen_ondulada = np.array(byte_array_ondulado).reshape(alto, ancho)

# Mostrar la imagen ondulada
cv2.imshow('Imagen Ondulada', imagen_ondulada)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import os

# Ruta de la imagen
imagen_path = '/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiro.jpg'
archivo_txt_path = '/home/daval/Escritorio/Arqui/Proyecto_1/emadrigal_computer_architecture_1_2023_s2/assets/sekiroPixeles.txt'

# Verificar si la imagen existe
if not os.path.exists(imagen_path):
    print(f"La imagen '{imagen_path}' no existe.")
else:
    # Cargar la imagen
    imagen = cv2.imread(imagen_path)

    if imagen is not None:
        # Cambiar la dimensión a 640x480
        nueva_dimension = (640, 480)
        imagen_redimensionada = cv2.resize(imagen, nueva_dimension)

        # Convertir la imagen a escala de grises
        imagen_gris = cv2.cvtColor(imagen_redimensionada, cv2.COLOR_BGR2GRAY)

        # Obtener las dimensiones de la imagen
        alto, ancho = imagen_gris.shape

        # Crear un archivo de texto para almacenar los valores de píxeles
        with open(archivo_txt_path, 'w') as archivo_txt:
            # Iterar a través de la imagen y escribir los valores de píxeles uno por uno en el archivo de texto
            for fila in range(alto):
                for columna in range(ancho):
                    valor_pixel = imagen_gris[fila, columna]
                    archivo_txt.write(str(valor_pixel) + '\n')

        print("Valores de píxeles guardados uno por uno en 'sekiroPixeles.txt'")
    else:
        print(f"No se pudo cargar la imagen '{imagen_path}'.")
# Out:
# Valores de píxeles guardados uno por uno en 'sekiroPixeles.txt'

# %%
# Abre el archivo en modo lectura
with open('INPUT.txt', 'r') as archivo:
    # Lee las líneas del archivo y convierte los valores en una lista
    lista_valores = [int(linea.strip()) for linea in archivo]

# Imprime la lista de valores
print(lista_valores)
# Out:
# [85, 82, 80, 80, 80, 79, 79, 81, 81, 81, 80, 82, 82, 82, 82, 82, 80, 80, 80, 82, 82, 83, 83, 83, 83, 83, 82, 83, 83, 80, 81, 82, 82, 82, 82, 82, 82, 82, 82, 82, 81, 83, 83, 83, 83, 83, 83, 81, 82, 82, 82, 82, 82, 86, 86, 86, 83, 83, 83, 85, 86, 87, 87, 87, 87, 87, 87, 85, 85, 84, 84, 84, 86, 86, 86, 88, 88, 87, 87, 87, 87, 88, 89, 87, 87, 87, 87, 87, 88, 88, 88, 87, 87, 90, 90, 90, 91, 91, 91, 91, 91, 90, 90, 90, 91, 91, 91, 91, 91, 92, 92, 92, 90, 91, 92, 93, 93, 92, 92, 92, 93, 93, 93, 93, 93, 93, 93, 93, 94, 94, 94, 94, 95, 96, 96, 96, 94, 95, 95, 96, 96, 96, 96, 96, 96, 96, 96, 96, 96, 97, 97, 97, 96, 96, 96, 97, 97, 98, 98, 98, 98, 98, 98, 98, 98, 97, 98, 99, 99, 99, 99, 100, 100, 101, 101, 101, 100, 100, 100, 102, 102, 103, 103, 103, 104, 104, 104, 104, 104, 105, 105, 106, 106, 107, 108, 107, 107, 107, 107, 108, 108, 109, 110, 111, 111, 112, 112, 113, 112, 113, 113, 114, 115, 115, 116, 116, 118, 119, 120, 119, 119, 119, 120, 121, 119, 120, 121, 123, 124, 123, 124, 125, 126, 127, 128, 128, 128, 129, 130, 131, 132, 133, 134, 134, 135, 137, 138, 139, 139, 140, 141, 140, 141, 143, 144, 145, 143, 144, 145, 146, 147, 159, 171, 172, 169, 169, 168, 171, 172, 171, 172, 177, 180, 178, 176, 176, 176, 180, 180, 180, 179, 178, 178, 175, 175, 173, 176, 178, 180, 180, 180, 180, 180, 182, 182, 182, 182, 182, 182, 183, 184, 183, 184, 183, 183, 183, 183, 184, 184, 182, 180, 178, 177, 177, 177, 180, 183, 179, 178, 174, 174, 171, 169, 171, 169, 168, 169, 161, 151, 146, 144, 144, 146, 145, 144, 143, 142, 141, 141, 140, 139, 137, 137, 136, 135, 135, 134, 133, 132, 131, 131, 130, 130, 130, 130, 129, 128, 128, 127, 126, 126, 125, 124, 123, 123, 123, 122, 121, 121, 122, 121, 121, 120, 117, 121, 123, 124, 129, 131, 135, 138, 134, 132, 133, 133, 132, 133, 128, 125, 127, 126, 136, 134, 120, 115, 111, 112, 112, 109, 108, 105, 102, 102, 104, 102, 101, 102, 101, 102, 104, 105, 105, 102, 103, 103, 102, 101, 99, 99, 100, 100, 102, 105, 98, 97, 99, 100, 99, 100, 94, 98, 99, 99, 97, 95, 94, 95, 95, 96, 99, 95, 92, 93, 94, 98, 102, 94, 93, 94, 95, 92, 97, 101, 98, 96, 92, 89, 91, 93, 89, 91, 92, 92, 92, 93, 92, 95, 96, 96, 94, 94, 94, 96, 96, 96, 96, 96, 97, 97, 97, 95, 95, 95, 95, 95, 95, 94, 95, 95, 94, 93, 94, 92, 95, 94, 93, 93, 93, 93, 91, 91, 91, 91, 91, 93, 93, 93, 93, 93, 91, 93, 93, 90, 90, 90, 92, 91, 90, 90, 90, 91, 91, 91, 89, 88, 88, 88, 88, 89, 89, 89, 90, 90, 90, 90, 90, 87, 87, 87, 87, 87, 87, 87, 87, 89, 90, 90, 87, 87, 88, 88, 88, 85, 85, 85, 87, 87, 89, 89, 89, 85, 85, 85, 88, 88, 86, 86, 86, 88, 88, 88, 85, 85, 85, 85, 85, 84, 84, 84, 87, 87, 85, 85, 85, 84, 84, 84, 88, 88, 87, 87, 87, 86, 86, 86, 87, 87, 88, 88, 88, 88, 88, 88, 86, 86, 91, 91, 90, 89, 89, 89, 89, 89, 90, 90, 90, 90, 90, 90, 87, 87, 89, 89, 89, 86, 86, 86, 86, 86, 87, 87, 87, 87, 87, 85, 87, 87, 86, 86, 87, 101, 97, 95, 95, 95, 96, 95, 94, 94, 94, 94, 98, 98, 95, 95, 95, 96, 96, 96, 95, 95, 99, 99, 99, 96, 96, 96, 101, 101, 96, 96, 97, 97, 97, 97, 98, 98, 98, 98, 98, 97, 97, 98, 101, 101, 98, 98, 98, 98, 98, 98, 97, 97, 103, 103, 103, 98, 98, 98, 101, 102, 103, 103, 103, 103, 103, 103, 102, 102, 103, 103, 103, 105, 105, 105, 104, 104, 104, 104, 104, 102, 103, 104, 104, 104, 105, 105, 105, 104, 104, 104, 105, 105, 104, 104, 104, 105, 105, 105, 105, 105, 109, 109, 109, 107, 107, 107, 107, 107, 109, 109, 109, 108, 109, 109, 108, 108, 109, 109, 109, 110, 110, 110, 110, 110, 110, 110, 110, 111, 111, 111, 111, 112, 111, 112, 111, 111, 112, 113, 113, 113, 113, 113, 113, 113, 113, 113, 114, 114, 114, 114, 114, 113, 113, 113, 114, 115, 115, 115, 115, 115, 115, 115, 116, 116, 115, 117, 117, 117, 117, 117, 118, 118, 120, 120, 120, 120, 119, 120, 121, 121, 123, 123, 123, 123, 123, 123, 124, 124, 124, 124, 126, 124, 125, 126, 127, 127, 126, 127, 128, 128, 128, 129, 129, 129, 130, 131, 132, 132, 133, 133, 134, 135, 135, 136, 137, 135, 136, 136, 139, 139, 139, 140, 141, 141, 142, 143, 144, 145, 145, 146, 147, 146, 147, 148, 147, 147, 149, 149, 150, 152, 152, 153, 154, 155, 156, 157, 1 ...

# %%
import subprocess

# Ejecuta el comando "./t2" y captura la salida estándar
output = subprocess.check_output(["./main"], universal_newlines=True)

# Divide la salida en líneas y convierte cada línea en un entero
values = [int(line.strip()) for line in output.splitlines()]

# Ahora, 'values' es una lista que contiene los valores capturados
print(values)
# Out:
# [85, 82, 80, 80, 80, 79, 79, 81, 81, 81, 80, 94, 82, 82, 82, 82, 80, 80, 80, 82, 82, 83, 83, 83, 83, 83, 82, 83, 83, 80, 81, 82, 82, 82, 82, 82, 82, 82, 82, 82, 81, 83, 83, 83, 83, 83, 83, 81, 82, 82, 82, 82, 82, 86, 86, 90, 83, 83, 83, 85, 86, 87, 87, 87, 87, 87, 87, 85, 85, 84, 84, 84, 86, 86, 86, 88, 88, 87, 87, 87, 87, 88, 89, 87, 87, 87, 87, 87, 88, 88, 88, 87, 87, 90, 90, 90, 91, 91, 91, 87, 91, 90, 90, 90, 91, 91, 91, 91, 91, 92, 92, 92, 90, 91, 92, 93, 93, 92, 92, 92, 93, 93, 93, 93, 93, 93, 93, 93, 94, 94, 94, 94, 95, 96, 96, 96, 94, 95, 95, 96, 96, 96, 96, 96, 96, 96, 96, 96, 96, 97, 97, 97, 96, 96, 96, 97, 97, 98, 98, 98, 98, 98, 98, 98, 98, 97, 98, 99, 99, 99, 99, 100, 100, 101, 101, 101, 100, 100, 100, 102, 102, 103, 103, 103, 104, 104, 104, 104, 104, 105, 105, 106, 106, 107, 108, 107, 107, 107, 107, 108, 108, 109, 110, 111, 111, 112, 112, 113, 112, 113, 113, 114, 115, 115, 116, 116, 118, 119, 120, 119, 119, 119, 120, 121, 119, 120, 121, 123, 124, 123, 124, 125, 126, 127, 128, 128, 128, 129, 130, 131, 132, 133, 134, 134, 135, 137, 138, 139, 139, 140, 141, 140, 141, 143, 144, 145, 143, 144, 145, 146, 147, 159, 171, 172, 169, 169, 168, 171, 172, 171, 172, 177, 180, 178, 176, 176, 176, 180, 180, 180, 179, 178, 178, 175, 175, 173, 176, 178, 180, 180, 180, 180, 180, 182, 182, 182, 182, 182, 182, 183, 113, 183, 184, 183, 183, 183, 183, 184, 184, 182, 180, 178, 177, 177, 177, 180, 183, 179, 178, 174, 174, 171, 169, 171, 169, 168, 169, 161, 151, 146, 144, 144, 146, 145, 144, 143, 142, 141, 141, 140, 139, 137, 137, 136, 123, 135, 134, 133, 132, 131, 131, 130, 130, 130, 130, 129, 128, 128, 127, 126, 126, 125, 124, 123, 123, 123, 122, 121, 121, 122, 121, 121, 120, 117, 121, 123, 124, 129, 131, 135, 138, 134, 132, 133, 133, 132, 133, 128, 145, 127, 126, 136, 134, 120, 115, 111, 112, 112, 109, 108, 105, 102, 102, 104, 102, 101, 102, 101, 102, 104, 105, 105, 102, 103, 103, 102, 101, 99, 99, 100, 100, 102, 105, 98, 97, 99, 100, 99, 100, 94, 98, 99, 209, 97, 95, 94, 95, 95, 96, 99, 95, 92, 93, 94, 98, 102, 94, 93, 94, 95, 92, 97, 101, 98, 96, 92, 89, 91, 93, 89, 91, 92, 92, 92, 93, 92, 95, 96, 96, 94, 94, 94, 96, 96, 96, 96, 96, 97, 97, 97, 95, 95, 95, 95, 95, 95, 94, 95, 95, 94, 93, 167, 92, 95, 94, 93, 93, 93, 93, 91, 91, 91, 91, 91, 93, 93, 93, 93, 93, 91, 93, 93, 90, 90, 90, 92, 91, 90, 90, 90, 91, 91, 91, 89, 88, 88, 88, 88, 89, 89, 89, 90, 90, 90, 90, 144, 87, 87, 87, 87, 87, 87, 87, 87, 89, 90, 90, 87, 87, 88, 88, 88, 85, 85, 85, 87, 87, 89, 89, 89, 85, 85, 85, 88, 88, 86, 86, 86, 88, 88, 88, 85, 85, 85, 85, 85, 84, 84, 84, 115, 87, 85, 85, 85, 84, 84, 84, 88, 88, 87, 87, 87, 86, 86, 86, 87, 87, 88, 88, 88, 88, 88, 88, 86, 86, 91, 91, 90, 89, 89, 89, 89, 89, 90, 90, 90, 90, 90, 90, 87, 87, 89, 89, 89, 86, 86, 86, 86, 86, 87, 87, 87, 87, 87, 85, 87, 87, 86, 86, 87, 101, 97, 95, 95, 95, 96, 95, 94, 94, 94, 94, 98, 98, 95, 95, 95, 96, 96, 96, 95, 95, 99, 99, 99, 96, 96, 96, 101, 101, 96, 96, 97, 97, 97, 97, 98, 98, 98, 98, 98, 97, 97, 98, 101, 101, 98, 98, 98, 98, 98, 98, 97, 97, 103, 103, 103, 98, 98, 98, 101, 102, 103, 103, 103, 103, 103, 103, 102, 102, 103, 103, 103, 105, 105, 105, 104, 104, 104, 104, 104, 102, 103, 104, 104, 104, 105, 105, 105, 104, 104, 104, 105, 105, 104, 104, 104, 105, 105, 105, 105, 105, 109, 109, 109, 107, 107, 107, 107, 107, 109, 109, 109, 108, 109, 109, 108, 108, 109, 109, 109, 110, 110, 110, 110, 110, 110, 110, 110, 111, 111, 111, 111, 112, 111, 112, 111, 111, 112, 113, 113, 106, 113, 113, 113, 113, 113, 113, 114, 114, 114, 114, 114, 113, 113, 113, 114, 115, 115, 115, 115, 115, 115, 115, 116, 116, 115, 117, 117, 117, 117, 117, 118, 118, 120, 120, 120, 120, 119, 120, 121, 121, 123, 123, 123, 97, 123, 123, 124, 124, 124, 124, 126, 124, 125, 126, 127, 127, 126, 127, 128, 128, 128, 129, 129, 129, 130, 131, 132, 132, 133, 133, 134, 135, 135, 136, 137, 135, 136, 136, 139, 139, 139, 140, 141, 141, 142, 143, 144, 105, 145, 146, 147, 146, 147, 148, 147, 147, 149, 149, 150, 152, 152, 153, 154, 155, 156, 157 ...

# %%
print(len(values))
# Out:
# 307200

# %%
def comparar_listas(lista1, lista2):
    if len(lista1) != len(lista2):
        raise ValueError("Las listas deben tener la misma longitud")

    diferencias = []
    for i in range(len(lista1)):
        if lista1[i] != lista2[i]:
            diferencias.append(i)

    return diferencias

diferencias = comparar_listas(lista_valores, values)

print("Las diferencias se encuentran en las posiciones:", diferencias)
# Out:
# Las diferencias se encuentran en las posiciones: [307199]

# %%
from PIL import Image

# Supongamos que 'values' contiene tus 307200 valores

# Crea una matriz de 640x480 a partir de 'values'
width, height = 640, 480
matrix = [values[i:i+width] for i in range(0, len(values), width)]

# Convierte la matriz en una imagen
image = Image.new("L", (width, height))  # "L" significa escala de grises
image.putdata([pixel for row in matrix for pixel in row])

# Guarda la imagen en un archivo (opcional)
image.save("../assets/imagen.png")

# Para mostrar la imagen (opcional)
image.show()
# Out:
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/daval/snap/code/common/.cache/gio-modules/libgiolibproxy.so
# eog: symbol lookup error: /snap/core20/current/lib/x86_64-linux-gnu/libpthread.so.0: undefined symbol: __libc_pthread_init, version GLIBC_PRIVATE

# %%
import math

X_original = 320  # Cambia este valor según tu valor original de X (en el rango de 0 a 640)

# Aplica la transformación de escala para obtener X en el rango de 0 a 2π
X_nuevo = (2 * math.pi / 640) * X_original

# Calcula el seno de X_nuevo
resultado = math.sin(X_nuevo)
a = math.sin(X_original)
print(resultado)
print(" ")
print(a)
# Out:
# 1.2246467991473532e-16
#
# -0.42815542808445156
